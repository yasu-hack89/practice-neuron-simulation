# %% [markdown]
# <a href="https://colab.research.google.com/github/yasu-hack89/practice-neuron-simulation/blob/main/2_practice_neuron_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
time=np.array([0,1,2,3,4,5,6,7])
voltage=np.array([-68,-66,-64,-62,-60,-58,-56,-54])
print(time)
print(voltage)
print(type(voltage))
# Out:
# [0 1 2 3 4 5 6 7]
# [-68 -66 -64 -62 -60 -58 -56 -54]
# <class 'numpy.ndarray'>

# %%
voltage_list=[-68,-66,-64,-62,-58,-56,-54]
print(voltage_list+10)
voltage_array=np.array([-68,-66,-64,-62,-58,-56,-54])
print(voltage_array+10)
print(voltage*2)
print(voltage_array.mean())
print(voltage_array.max())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9184/529555056.py in <cell line: 0>()
#       1 voltage_list=[-68,-66,-64,-62,-58,-56,-54]
# ----> 2 print(voltage_list+10)
#       3 voltage_array=np.array([-68,-66,-64,-62,-58,-56,-54])
#       4 print(voltage_array+10)
#       5 print(voltage*2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
np.array([1,2,3])+10
# Out:
# array([11, 12, 13])

# %%
print(voltage_array * 2)
print(voltage_array.mean())
print(voltage_array.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9184/1899676158.py in <cell line: 0>()
# ----> 1 print(voltage_array * 2)
#       2 print(voltage_array.mean())
#       3 print(voltage_array.max())
#
# NameError: name 'voltage_array' is not defined

# %%
np.array([1,2,3])+10
print(voltage_array * 2)
print(voltage_array.mean())
print(voltage_array.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9184/826997357.py in <cell line: 0>()
#       1 np.array([1,2,3])+10
# ----> 2 print(voltage_array * 2)
#       3 print(voltage_array.mean())
#       4 print(voltage_array.max())
#
# NameError: name 'voltage_array' is not defined

# %%
voltage_list=[-68,-66,-64,-62,-58,-56,-54]
np.array([1,2,3])+10

voltage_array=np.array([-68,-66,-64,-62,-58,-56,-54])
print(voltage_array+10)
print(voltage*2)
print(voltage_array.mean())
print(voltage_array.max())
# Out:
# [-58 -56 -54 -52 -48 -46 -44]
# [-136 -132 -128 -124 -120 -116 -112 -108]
# -61.142857142857146
# -54

# %%
print(voltage_array)
print(len(voltage_array))
# Out:
# [-68 -66 -64 -62 -58 -56 -54]
# 7

# %%
voltage_list=[-68,-66,-64,-62,-60,-58,-56,-54]
np.array([1,2,3])+10

voltage_array=np.array([-68,-66,-64,-62,-60,-58,-56,-54])
print(voltage_array+10)
print(voltage*2)
print(voltage_array.mean())
print(voltage_array.max())
# Out:
# [-58 -56 -54 -52 -50 -48 -46 -44]
# [-136 -132 -128 -124 -120 -116 -112 -108]
# -61.0
# -54

# %%
print(valtage_array[0])
print(valtage_array[-1])
print(valtage_array[2:5])
print(valtage_array[:3])
print(valtage_array[3:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9184/3362225616.py in <cell line: 0>()
# ----> 1 print(valtage_array[0])
#       2 print(valtage_array[-1])
#       3 print(valtage_array[2:5])
#       4 print(valtage_array[:3])
#       5 print(valtage_array[3:])
#
# NameError: name 'valtage_array' is not defined

# %%
voltage_list=[-68,-66,-64,-62,-60,-58,-56,-54]
np.array([1,2,3])+10

voltage_array=np.array([-68,-66,-64,-62,-60,-58,-56,-54])
print(voltage_array+10)
print(voltage*2)
print(voltage_array.mean())
print(voltage_array.max())

print(voltage_array[0])
print(voltage_array[-1])
print(voltage_array[2:5])
print(voltage_array[:3])
print(voltage_array[3:])
# Out:
# [-58 -56 -54 -52 -50 -48 -46 -44]
# [-136 -132 -128 -124 -120 -116 -112 -108]
# -61.0
# -54
# -68
# -54
# [-64 -62 -60]
# [-68 -66 -64]
# [-62 -60 -58 -56 -54]

# %%
print(voltage_array[0])
print(voltage_array[-1])
print(voltage_array[2:5])
print(voltage_array[:3])
print(voltage_array[3:])
# Out:
# -68
# -54
# [-64 -62 -60]
# [-68 -66 -64]
# [-62 -60 -58 -56 -54]

# %%
import matplotlib.pyplot as plt

time=np.arange(8)
voltage_array=np.array([-68,-66,-64,-62,-60,-58,-56,-54])

plt.plot(time, voltage_array, marker='o')
plt.axhline(y=-55.0, color='red', linestyle='--', label='threshold')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (mV)')
plt.legend()
plt.show()
